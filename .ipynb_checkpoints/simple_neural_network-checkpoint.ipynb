# %% [markdown]
# # Temperature Conversion with Neural Networks
#
# **Objective:**
#
# This notebook presents a basic example of using a neural network to convert Celsius to Fahrenheit.

# %%
import keras

from keras import layers

import tensorflow as tf
import numpy as np

# %%
celsious = np.array([-40,-10,0,8,15,22,38],dtype=float)
fahrenheit = np.array([-40,14,32,46,59,72,100],dtype=float)

# %%
model = keras.Sequential(
    [
        layers.Input(shape=(1,)),
        layers.Dense(1),
    ]
)

# %%
model.compile(
    optimizer=keras.optimizers.Adam(0.1),
    loss='mean_absolute_error'
)

# %%
print('start training')
historial = model.fit(celsious,fahrenheit,epochs=400,verbose=False)
print('model trained')
# Out:
# start training
# model trained

# %%
import matplotlib.pyplot as plt
plt.xlabel('Epoch')
plt.ylabel('Loss magnitude')
plt.plot(historial.history['loss'])

# %%
print('Lets Predict!')
result = model.predict(x=np.array([100.0]))
print('Result: ' + str(result))
# Out:
# Lets Predict!
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# Result: [[212.9652]]

# %%
print('Layer weights')
print(model.layers[0].get_weights())
# Out:
# Layer weights
# [array([[1.8096281]], dtype=float32), array([32.002384], dtype=float32)]
